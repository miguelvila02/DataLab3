# %%
import soccerdata as sd

mh = sd.MatchHistory(leagues="ENG-Premier League", seasons="2020")
print(mh.__doc__)
# Out:
# [11/26/25 11:53:50] INFO     No custom team name replacements found. You can configure these in       ]8;id=663754;file:///home/miguelvila/miniconda3/envs/soccer/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=525331;file:///home/miguelvila/miniconda3/envs/soccer/lib/python3.12/site-packages/soccerdata/_config.py#91\91]8;;\
#                              /home/miguelvila/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=177943;file:///home/miguelvila/miniconda3/envs/soccer/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=46735;file:///home/miguelvila/miniconda3/envs/soccer/lib/python3.12/site-packages/soccerdata/_config.py#197\197]8;;\
#                              /home/miguelvila/soccerdata/config/league_dict.json.
# ...
